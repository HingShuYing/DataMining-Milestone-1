# %%
import pandas as pd
from bs4 import BeautifulSoup as soup
import requests
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import datetime

# %%
my_url='https://www.skyscanner.com.my/transport/flights-from/kulm/200318/210312/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=1&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home'

# %%
html=requests.get(my_url)

# %%
soup1=soup(html.content,'html.parser')

# %%
print(soup1.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en-GB">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale = 1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
#    <meta content="#0770e3" name="theme-color"/>
#    <meta content="#0770e3" name="msapplication-TileColor">
#     <link href="/android-chrome-manifest.json" rel="manifest"/>
#     <title>
#      Cheap flights from Kuala Lumpur at Skyscanner
#     </title>
#     <link href="//api.mixpanel.com" rel="dns-prefetch"/>
#     <link href="https://secure.skyscanner.net" rel="dns-prefetch"/>
#     <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#     <link href="//cdn.mxpnl.com" rel="dns-prefetch"/>
#     <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#     <link href="//analytics.skyscanner.net" rel="dns-prefetch"/>
#     <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR">
# ...

# %%
print(html)
# Out:
# <Response [200]>

# %%
title=soup1.find_all('label',{'id':'Destination'})
print(title)
# Out:
# []

# %%
city_list = soup.find(attrs={'class': 'city-list everywhere'}).find_all('li')
for li in city_list:
    for a in li.find_all('h3'):
                flights[a.get_text()] = url + h3['href'][9:]
        return flights
# Out:
#   File "<tokenize>", line 5
#     return flights
#     ^
# IndentationError: unindent does not match any outer indentation level
